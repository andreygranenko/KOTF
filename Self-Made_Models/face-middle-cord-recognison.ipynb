# %% [markdown]
# <a href="https://www.kaggle.com/code/teodorchaly/face-middle-cord-recognison?scriptVersionId=153412186" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Загрузка данных из файла .npz
data = np.load('/kaggle/input/face-images-with-marked-landmark-points/face_images.npz')

images = data['face_images']
df =  pd.read_csv('/kaggle/input/face-images-with-marked-landmark-points/facial_keypoints.csv')

images = np.swapaxes(np.swapaxes(images, 1, 2), 0, 1)
plt.imshow(images[0])

# %%
null_rows = df[['left_eye_center_x', 'left_eye_center_y', 'right_eye_center_x', 'right_eye_center_y']].isnull().any(axis=1) # Check 
null_indices = null_rows[null_rows].index
null_indices
# Out:
# Index([1620, 1643, 1687, 1834, 1866, 1912, 1938, 2090, 2095, 2099, 2100, 2137,
#        2153, 2175, 2186, 2239],
#       dtype='int64')
